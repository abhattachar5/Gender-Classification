# %%
import cv2 
import numpy as np  
import matplotlib.pyplot as plt
# %matplotlib inline

image = cv2.imread('C:/Users/Administrator/Desktop/KM/Gender Detection/UKTImagesdataset/UTKFace/18_0_0_20170110231625906.jpg.chip.jpg')
image_Copy = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_Copy)

# %%
image_Copy.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-b3a5a851ae11> in <module>
# ----> 1 image_Copy.type()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
import os
import shutil

PATTERN_1 = "_1_0_2"
PATTERN_2 = "_1_1_2"
PATTERN_3 = "_1_2_2"
PATTERN_4 = "_1_3_2"
PATTERN_5 = "_1_4_2"

#PATTERN_END = ".jpg"
CURRENT_DIR = os.path.dirname('C:\\Users\\Administrator\\Desktop\\KM\\Gender Detection\\UKTImagesdataset\\UTKFace\\')
destination = os.path.dirname('C:\\Users\\Administrator\\Desktop\\KM\\Gender Detection\\UKTImagesdataset\\Female\\')
#print(CURRENT_DIR)

for r,d,FILES in os.walk(CURRENT_DIR):
    for FILE in FILES:
        if PATTERN_1 in FILE or PATTERN_2 in FILE or PATTERN_3 in FILE or PATTERN_4 in FILE or PATTERN_5 in FILE  :
            src = os.path.join(CURRENT_DIR, FILE)
            filename = os.path.join(destination, FILE)
            #copyfile(src, filename)
            #print(filename)
            shutil.copy(src,filename)
            #print(src)
            #print(filename)

# %%
import os
import shutil

PATTERN_1 = "_0_0_2"
PATTERN_2 = "_0_1_2"
PATTERN_3 = "_0_2_2"
PATTERN_4 = "_0_3_2"
PATTERN_5 = "_0_4_2"

#PATTERN_END = ".jpg"
CURRENT_DIR = os.path.dirname('C:\\Users\\Administrator\\Desktop\\KM\\Gender Detection\\UKTImagesdataset\\UTKFace\\')
destination = os.path.dirname('C:\\Users\\Administrator\\Desktop\\KM\\Gender Detection\\UKTImagesdataset\\Male\\')
#print(CURRENT_DIR)

for r,d,FILES in os.walk(CURRENT_DIR):
    for FILE in FILES:
        if PATTERN_1 in FILE or PATTERN_2 in FILE or PATTERN_3 in FILE or PATTERN_4 in FILE or PATTERN_5 in FILE  :
            src = os.path.join(CURRENT_DIR, FILE)
            filename = os.path.join(destination, FILE)
            #copyfile(src, filename)
            #print(filename)
            shutil.copy(src,filename)
            #print(src)
            #print(filename)
